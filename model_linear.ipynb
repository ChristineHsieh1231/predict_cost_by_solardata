# %% [markdown]
# # **封包與資料**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from keras import models
from keras import layers
import matplotlib.pyplot as plt
from sklearn import linear_model
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline
from sklearn.datasets import make_regression
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import SelectKBest, chi2

# %%
data=pd.read_csv('/Users/christine_sieh/workspace/Electric price_caculator/#1 dataclean/sunroof_train.csv',header=0)
data
# Out:
#        Unnamed: 0  Electricity_cost_total         county state    lat_avg  \
# 0               1              14436100.8  Acadia Parish    la  30.256188
# 1               2              14436100.8  Acadia Parish    la  30.256188
# 2               4              14436100.8  Acadia Parish    la  30.256188
# 3               5              14436100.8  Acadia Parish    la  30.256188
# 4               6              14436100.8  Acadia Parish    la  30.256188
# ...           ...                     ...            ...   ...        ...
# 41989       56419              20934777.6    Yuma County    az  32.665432
# 41990       56420              20934777.6    Yuma County    az  32.665432
# 41991       56421              20934777.6    Yuma County    az  32.665432
# 41992       56422              20934777.6    Yuma County    az  32.665432
# 41993       56423              20934777.6    Yuma County    az  32.665432
#
#           lng_avg  yearly_sunlight_kwh_kw_threshold_avg  count_qualified  \
# 0      -92.331117                           1073.550000               28
# 1      -92.331117                           1073.550000               28
# 2      -92.331117                           1073.550000               28
# 3      -92.331117                           1073.550000               28
# 4      -92.331117                           1073.550000               28
# ...           ...                                   ...              ...
# 41989 -114.575738                           1376.070522            36880
# 41990 -114.575738                           1376.070522            36880
# 41991 -114.575738                           1376.070522            36880
# 41992 -114.575738                           1376.070522            36880
# 41993 -114.575738                           1376.070522            36880
#
#        number_of_panels_n  number_of_panels_s  ...  \
# 0                     126                 342  ...
# 1                     126                 342  ...
# 2                     126                 342  ...
# 3                     126                 342  ...
# 4                     126                 342  ...
# ...                   ...                 ...  ...
# 41989              145848              473170  ...
# 41990              145848              473170  ...
# 41991              145848              473170  ...
# 41992              145848              473170  ...
# 41993              145848              473170  ...
#
#        incentive_count_nonresidential  incentive_residential_state_level  \
# 0                                  17                                  7
# 1                                  17                                  7
# 2                                  17                                  7
# 3                                  17                                  7
# 4                                  17                                  7
# ...                               ...                                ...
# 41989                              41                                  8
# 41990                              41                                  8
# 41991                              41                                  8
# 41992                              41                                  8
# 41993                              41                                  8
#
#        incentive_nonresidential_state_level  net_metering  feedin_tariff  \
# 0                                         4            14              0
# 1                                         4            14              0
# 2                                         4            14              0
# 3                                         4            14              0
# 4                                         4            14              0
# ...                                     ...           ...            ...
# 41989                                    15             8              0
# 41990                                    15             8              0
# 41991                                    15             8              0
# 41992                                    15             8              0
# 41993                                    15             8              0
#
#        cooperate_tax  property_tax  sales_tax  rebate  \
# 0                  0            23          0       0
# 1                  0            23          0       0
# 2                  0            23          0       0
# 3                  0            23          0       0
# 4                  0            23          0       0
# ...              ...           ...        ...     ...
# 41989              0            11         20       0
# 41990              0            11         20       0
# 41991              0            11         20       0
# 41992              0            11         20       0
# 41993              0            11         20       0
#
#        avg_electricity_retail_rate
# 0                             7.63
# 1                             7.63
# 2                             7.63
# 3                             7.63
# 4                             7.63
# ...                            ...
# 41989                        10.15
# 41990                        10.15
# 41991                        10.15
# 41992                        10.15
# 41993                        10.15
#
# [41994 rows x 149 columns]

# %%
data.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41994 entries, 0 to 41993
# Data columns (total 149 columns):
#  #    Column                                Dtype
# ---   ------                                -----
#  0    Unnamed: 0                            int64
#  1    Electricity_cost_total                float64
#  2    county                                object
#  3    state                                 object
#  4    lat_avg                               float64
#  5    lng_avg                               float64
#  6    yearly_sunlight_kwh_kw_threshold_avg  float64
#  7    count_qualified                       int64
#  8    number_of_panels_n                    int64
#  9    number_of_panels_s                    int64
#  10   number_of_panels_e                    int64
#  11   number_of_panels_w                    int64
#  12   number_of_panels_f                    int64
#  13   number_of_panels_median               float64
#  14   kw_median                             float64
#  15   kw_total                              float64
#  16   yearly_sunlight_kwh_n                 float64
#  17   yearly_sunlight_kwh_s                 float64
#  18   yearly_sunlight_kwh_e                 float64
#  19   yearly_sunlight_kwh_w                 float64
#  20   yearly_sunlight_kwh_f                 float64
#  21   yearly_sunlight_kwh_median            float64
#  22   carbon_offset_metric_tons             float64
#  23   existing_installs_count               int64
#  24   total_panel_area                      float64
#  25   fips                                  int64
#  26   average_household_income              float64
#  27   education_bachelor                    int64
#  28   education_college                     int64
#  29   education_doctoral                    int64
#  30   education_high_school_graduate        int64
#  31   education_less_than_high_school       int64
#  32   education_master                      int64
#  33   education_population                  int64
#  34   education_professional_school         int64
#  35   employed                              int64
#  36   gini_index                            float64
#  37   heating_fuel_coal_coke                int64
#  38   heating_fuel_electricity              int64
#  39   heating_fuel_fuel_oil_kerosene        int64
#  40   heating_fuel_gas                      int64
#  41   heating_fuel_housing_unit_count       int64
#  42   heating_fuel_none                     int64
#  43   heating_fuel_other                    int64
#  44   heating_fuel_solar                    int64
#  45   land_area                             float64
#  46   per_capita_income                     float64
#  47   population                            int64
#  48   population_density                    float64
#  49   poverty_family_below_poverty_level    int64
#  50   poverty_family_count                  int64
#  51   race_asian                            int64
#  52   race_black_africa                     int64
#  53   race_indian_alaska                    int64
#  54   race_islander                         int64
#  55   race_other                            int64
#  56   race_two_more                         int64
#  57   race_white                            int64
#  58   total_area                            float64
#  59   unemployed                            int64
#  60   water_area                            float64
#  61   solar_system_count_residential        int64
#  62   solar_system_count_nonresidential     int64
#  63   total_panel_area_residential          float64
#  64   total_panel_area_nonresidential       float64
#  65   median_household_income               float64
#  66   household_count                       int64
#  67   average_household_size                float64
#  68   housing_unit_count                    int64
#  69   housing_unit_occupied_count           int64
#  70   housing_unit_median_value             float64
#  71   housing_unit_median_gross_rent        float64
#  72   lat                                   float64
#  73   lon                                   float64
#  74   elevation                             float64
#  75   heating_design_temperature            float64
#  76   cooling_design_temperature            float64
#  77   earth_temperature_amplitude           float64
#  78   frost_days                            float64
#  79   air_temperature                       float64
#  80   relative_humidity                     float64
#  81   daily_solar_radiation                 float64
#  82   atmospheric_pressure                  float64
#  83   wind_speed                            float64
#  84   earth_temperature                     float64
#  85   heating_degree_days                   float64
#  86   cooling_degree_days                   float64
#  87   age_18_24_rate                        float64
#  88   age_25_34_rate                        float64
#  89   age_more_than_85_rate                 float64
#  90   age_75_84_rate                        float64
#  91   age_35_44_rate                        float64
#  92   age_45_54_rate                        float64
#  93   age_65_74_rate                        float64
#  94   age_55_64_rate                        float64
#  95   age_10_14_rate                        float64
#  96   age_15_17_rate                        float64
#  97   age_5_9_rate                          float64
#  98   household_type_family_rate            float64
#  99   dropout_16_19_inschool_rate           float64
#  100  occupation_construction_rate          float64
#  101  occupation_public_rate                float64
#  102  occupation_information_rate           float64
#  103  occupation_finance_rate               float64
#  104  occupation_education_rate             float64
#  105  occupation_administrative_rate        float64
#  106  occupation_manufacturing_rate         float64
#  107  occupation_wholesale_rate             float64
#  108  occupation_retail_rate                float64
#  109  occupation_transportation_rate        float64
#  110  occupation_arts_rate                  float64
#  111  occupation_agriculture_rate           float64
#  112  occupancy_vacant_rate                 float64
#  113  occupancy_owner_rate                  float64
#  114  mortgage_with_rate                    float64
#  115  transportation_home_rate              float64
#  116  transportation_car_alone_rate         float64
#  117  transportation_walk_rate              float64
#  118  transportation_carpool_rate           float64
#  119  transportation_motorcycle_rate        float64
#  120  transportation_bicycle_rate           float64
#  121  transportation_public_rate            float64
#  122  travel_time_less_than_10_rate         float64
#  123  travel_time_10_19_rate                float64
#  124  travel_time_20_29_rate                float64
#  125  travel_time_30_39_rate                float64
#  126  travel_time_40_59_rate                float64
#  127  travel_time_60_89_rate                float64
#  128  health_insurance_public_rate          float64
#  129  health_insurance_none_rate            float64
#  130  age_median                            float64
#  131  travel_time_average                   float64
#  132  voting_2016_dem_percentage            float64
#  133  voting_2016_gop_percentage            float64
#  134  voting_2012_dem_percentage            float64
#  135  voting_2012_gop_percentage            float64
#  136  number_of_years_of_education          float64
#  137  diversity                             float64
#  138  incentive_count_residential           int64
#  139  incentive_count_nonresidential        int64
#  140  incentive_residential_state_level     int64
#  141  incentive_nonresidential_state_level  int64
#  142  net_metering                          int64
#  143  feedin_tariff                         int64
#  144  cooperate_tax                         int64
#  145  property_tax                          int64
#  146  sales_tax                             int64
#  147  rebate                                int64
#  148  avg_electricity_retail_rate           float64
# dtypes: float64(95), int64(52), object(2)
# memory usage: 47.7+ MB

# %%
y=data.iloc[:,1] 
X=data.iloc[:,4:]

# %%
import tensorflow as tf
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.33, random_state=101)

# %%
X_train
# Out:
#          lat_avg     lng_avg  yearly_sunlight_kwh_kw_threshold_avg  \
# 4024   32.460384  -93.792777                               1075.25
# 22992  39.787649  -86.133906                                991.10
# 15918  38.364569  -81.680684                                967.30
# 646    40.446405  -79.963771                                948.60
# 32677  34.195701 -117.332870                               1447.55
# ...          ...         ...                                   ...
# 12363  38.552566  -82.760467                                986.00
# 5695   35.355135 -111.657306                               1396.55
# 8006   41.446526  -81.674658                                932.45
# 17745  41.647195  -86.813976                                954.55
# 17931  42.316312  -87.982641                                992.80
#
#        count_qualified  number_of_panels_n  number_of_panels_s  \
# 4024             61839              389431              941322
# 22992           252086              949430             3842438
# 15918            35695              156045              422743
# 646             283639              947681             2799719
# 32677           440268              538454             6387449
# ...                ...                 ...                 ...
# 12363             3221               15362               44305
# 5695             18145               38890              284531
# 8006            335386             1090154             4221993
# 17745             5959               33939               87775
# 17931            47230              117557              676147
#
#        number_of_panels_e  number_of_panels_w  number_of_panels_f  \
# 4024               610524              774652             2603903
# 22992             2106138             3017937             8440995
# 15918              343868              340406             1024294
# 646               2051441             2309508             6351232
# 32677             2806033             4761205            11681419
# ...                   ...                 ...                 ...
# 12363               29560               32664               84210
# 5695               179402              202154              600794
# 8006              1930982             3076757            11490674
# 17745               57460               73619              389301
# 17931              421627              522917             1111093
#
#        number_of_panels_median  ...  incentive_count_nonresidential  \
# 4024                      38.0  ...                              17
# 22992                     29.0  ...                              22
# 15918                     30.0  ...                              15
# 646                       23.0  ...                              31
# 32677                     32.0  ...                              85
# ...                        ...  ...                             ...
# 12363                     32.0  ...                              25
# 5695                      32.0  ...                              41
# 8006                      24.0  ...                              29
# 17745                     27.0  ...                              22
# 17931                     29.0  ...                              28
#
#        incentive_residential_state_level  \
# 4024                                   7
# 22992                                  4
# 15918                                  3
# 646                                    6
# 32677                                 15
# ...                                  ...
# 12363                                  4
# 5695                                   8
# 8006                                   7
# 17745                                  4
# 17931                                  7
#
#        incentive_nonresidential_state_level  net_metering  feedin_tariff  \
# 4024                                      4            14              0
# 22992                                     7            13              0
# 15918                                     2             8              0
# 646                                       9            12              0
# 32677                                    16            21              9
# ...                                     ...           ...            ...
# 12363                                     9            13              0
# 5695                                     15             8              0
# 8006                                     12            18              0
# 17745                                     7            13              0
# 17931                                     8             9              0
#
#        cooperate_tax  property_tax  sales_tax  rebate  \
# 4024               0            23          0       0
# 22992              0             7          0       0
# 15918              0             0          0       0
# 646                0             0          0       0
# 32677              0            38          0      10
# ...              ...           ...        ...     ...
# 12363              0             0          0       0
# 5695               0            11         20       0
# 8006               0             0          0       0
# 17745              0             7          0       0
# 17931              0            17          0       0
#
#        avg_electricity_retail_rate
# 4024                          7.63
# 22992                         8.86
# 15918                         8.16
# 646                          10.26
# 32677                        14.72
# ...                            ...
# 12363                         7.93
# 5695                         10.15
# 8006                          9.57
# 17745                         8.86
# 17931                         8.97
#
# [28135 rows x 145 columns]

# %% [markdown]
# # **線性迴歸**

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(X_train,y_train)
lr.coef_
# Out:
# array([ 1.50478353e+05, -6.49076896e+05, -1.71639445e+04, -9.37204006e+01,
#         1.31929513e+07,  1.31930521e+07,  1.31930316e+07,  1.31931109e+07,
#         1.31930660e+07, -9.51068403e+06,  4.89834372e+07, -5.27722450e+07,
#         3.58212802e-01,  4.93275392e-02,  1.06481394e-01, -1.87720335e-01,
#        -1.30732187e-02, -8.27334125e+03,  7.78932472e+00,  2.29628141e+02,
#        -7.58655255e+06,  7.10999407e-04, -1.36365505e+00, -2.02933433e+03,
#        -1.10662776e+03,  7.46487849e+03, -2.56982180e+03, -1.16253410e+03,
#        -7.18262943e+02,  3.49502808e+03,  3.65620121e+03,  1.24362791e+02,
#         1.04233402e+07, -4.47677084e+03,  1.02769072e+04, -7.28810386e+03,
#         5.42417394e+03, -3.55637029e+03,  1.56301513e+04,  2.28826498e+02,
#        -2.32986337e+04,  7.80890047e+09, -3.25299194e+01, -2.18109793e+03,
#        -2.43916643e+00, -2.34819554e+03,  5.25281932e+02,  1.56302453e+02,
#         9.92786955e+02,  1.27339417e+03, -5.20477578e+03,  1.99067576e+03,
#        -2.61779557e+03,  1.25395958e+03, -7.80889602e+09,  1.07901851e+04,
#         7.80893795e+09, -4.04411462e+04,  1.47871067e+04,  7.58807593e+06,
#         7.58658610e+06, -2.57361897e+01, -3.58860891e+03, -4.92573908e+05,
#         2.06042581e+03, -3.58927502e+03,  2.08944019e+00,  9.38223464e+02,
#        -1.40461922e+06, -8.26062930e+05,  2.84276922e+05, -1.35945122e+07,
#         5.14128159e+06, -6.31192815e+06,  4.48234791e+05, -3.94620756e+07,
#        -1.67922113e+08, -7.02031095e+06,  2.93697425e+07, -1.04626772e+07,
#         1.72536705e+07, -1.34706327e+05, -7.31348190e+03,  2.36960123e+07,
#         1.90362418e+07, -3.52456467e+07, -7.75903049e+06,  3.46740676e+07,
#         9.28020266e+06,  9.13060194e+06,  6.19898890e+06,  1.04693847e+07,
#         1.05451786e+07,  1.05415086e+07,  8.25725118e+05,  1.61440312e+06,
#        -1.30698485e+07, -1.54139362e+07, -1.50264417e+07, -1.78433918e+07,
#        -1.02117304e+07, -8.98757126e+06,  2.17288010e+07, -1.66755309e+07,
#        -2.49057946e+06,  3.21226598e+07,  1.33339827e+07, -9.75308943e+06,
#         1.68066674e+06,  5.74861601e+06,  4.87371224e+06,  1.28450260e+07,
#         7.13788818e+06, -4.92529538e+06,  5.25910451e+06, -3.81644920e+07,
#         3.13794360e+07, -4.92102318e+06,  2.31009113e+07,  2.16075057e+07,
#         1.49717247e+07,  2.28244046e+07,  2.79220420e+07,  2.69576780e+07,
#         2.11499671e+07, -1.97848089e+07,  9.78092762e+04,  1.27687082e+05,
#        -2.76371186e+08, -2.78782355e+08, -1.88202324e+08, -1.85950270e+08,
#         3.96309802e+05, -4.20370525e+06, -3.62549594e+06,  2.12866361e+06,
#         6.39161340e+05,  7.58703849e+05, -1.43985859e+06,  6.36370460e+05,
#        -4.44528326e+06,  9.11413878e+05, -2.47230937e+05, -1.62006449e+06,
#         4.66005954e+06])

# %%
lrtrain_score=lr.score(X_train, y_train)
print(lrtrain_score)
# Out:
# 0.613428626351272

# %% [markdown]
# ## **測試結果**

# %%
y_pred=lr.predict(X_test)

# %%
lrtest_score=lr.score(X_test, y_test)
print(lrtest_score)
# Out:
# 0.6060382014414476

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from math import sqrt
import numpy as np

MSE = mean_squared_error(y_test, y_pred)
print('MSE=',MSE)
RMSE =np.sqrt(MSE)
print('RMSE=',RMSE)
MAE= mean_absolute_error(y_test, y_pred)
print('MAE=',MAE)

R2=1-MSE/np.var(y_test)
print("R2:", R2)
# Out:
# MSE= 327667862464237.8
# RMSE= 18101598.340042733
# MAE= 11683945.559873296
# R2: 0.6060382014414476
